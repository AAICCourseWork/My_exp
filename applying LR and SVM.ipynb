# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import LogisticRegression
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, Normalizer
import matplotlib.pyplot as plt
from sklearn.svm import SVC
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Task 1: Applying SVM

# %%
def draw_line(coef,intercept, mi, ma):
    # for the separating hyper plane ax+by+c=0, the weights are [a, b] and the intercept is c
    # to draw the hyper plane we are creating two points
    # 1. ((b*min-c)/a, min) i.e ax+by+c=0 ==> ax = (-by-c) ==> x = (-by-c)/a here in place of y we are keeping the minimum value of y
    # 2. ((b*max-c)/a, max) i.e ax+by+c=0 ==> ax = (-by-c) ==> x = (-by-c)/a here in place of y we are keeping the maximum value of y
    points=np.array([[((-coef[1]*mi - intercept)/coef[0]), mi],[((-coef[1]*ma - intercept)/coef[0]), ma]])

    plt.plot(points[:,0], points[:,1])

# %%
# here we are creating 2d imbalanced data points 
import matplotlib.pyplot as plt
import numpy as np
from sklearn import preprocessing
from sklearn.svm import LinearSVC

def plott(X,y,j):
  
    
    plt.figure(figsize=(20,3))
    scaler = StandardScaler()
    X_std = scaler.fit_transform(X)
    lab_enc = preprocessing.LabelEncoder()
    Y_std = lab_enc.fit_transform(y)
    mi=min(X_std[:,1] )
    
    ma=max(X_std[:,1])
    c=[0.001,1,100]
    color = ['red' if c == 0 else 'blue' for c in y]
    k=1
    for i in c:
        
        svc1 =SVC(C=i,kernel='linear', random_state=0)
        model1 = svc1.fit(X_std,Y_std)
        plt.subplot(j,3,k)
        plt.scatter(X_std[:,0], X_std[:,1], c=color)
        # Create the hyperplane
        plt.scatter(model1.support_vectors_[:, 0],
                   model1.support_vectors_[:, 1],
                   s=1000, linewidth=1,marker='+');
        draw_line(svc1.coef_[0],svc1.intercept_,mi,ma)
        k=k+1
    j=j+1
    
    
    
   
    
        




X_point=[]
y_point=[]
ratios = [(100,2), (100, 20), (100, 40), (100, 80)]

d=[]
n=[]
X_point=[]
Y_point=[]
for j,i in enumerate(ratios):
    #plt.subplot(1, 4, j+1)
    X_p=np.random.normal(0,0.05,size=(i[0],2))
    
    X_n=np.random.normal(0.13,0.02,size=(i[1],2))
    y_p=np.array([1]*i[0]).reshape(-1,1)
    y_n=np.array([0]*i[1]).reshape(-1,1)
    X=np.vstack((X_p,X_n))
    y=np.vstack((y_p,y_n))
    j=1
    plott(X,y,j)

#star points indicate support vectors

# %%
 Observation: 
<p>1)when C=0.001 i.e., regularization is more,which leads to underfit
<p>2)when c=1 i.e., regularization term is also 1 which leads to best fit
<p>3)when c=100 i.e., regularization is small,which leads to overfit
<p>4)We can say that SVM is affected more by C value than the imbalanced data

<p>3)with change in C value to 1 for dataset D1,D2,D3,D4 SVM classifier is exactly classifying between +ve and -ve points
<p>4)with change in C value to 100 for dataset D1,D2,D3,D4 SVM classifier is trying to overfit as in Plane(SVM().fit(D4, C=100))

# %% [markdown]
# ## Task 2: Applying LR

# %%
   

# here we are creating 2d imbalanced data points 
import matplotlib.pyplot as plt
import numpy as np
from sklearn import preprocessing
from sklearn.svm import LinearSVC

def plott(X,y,j):
  
    
    plt.figure(figsize=(20,5))
    scaler = StandardScaler()
    X_std = scaler.fit_transform(X)
    lab_enc = preprocessing.LabelEncoder()
    Y_std = lab_enc.fit_transform(y)
    mi=min(X_std[:,1])
    ma=max(X_std[:,1])
    color = ['red' if c == 0 else 'blue' for c in y]
    c=[0.001,1,100]
    k=1
    for i in c:
        lr1= LogisticRegression(C=i)
        model = lr1.fit(X_std,Y_std)
        plt.subplot(j,3,k)
        plt.scatter(X_std[:,0], X_std[:,1], c=color)
        # Create the hyperplane
        draw_line(lr1.coef_[0],lr1.intercept_,mi,ma)
        k=k+1
    j=j+1
        
    
    
        




X_point=[]
y_point=[]
ratios = [(100,2), (100, 20), (100, 40), (100, 80)]

d=[]
n=[]
X_point=[]
Y_point=[]
for j,i in enumerate(ratios):
    #plt.subplot(1, 4, j+1)
    X_p=np.random.normal(0,0.05,size=(i[0],2))
    
    X_n=np.random.normal(0.13,0.02,size=(i[1],2))
    y_p=np.array([1]*i[0]).reshape(-1,1)
    y_n=np.array([0]*i[1]).reshape(-1,1)
    X=np.vstack((X_p,X_n))
    y=np.vstack((y_p,y_n))
    j=1
    plott(X,y,j)
